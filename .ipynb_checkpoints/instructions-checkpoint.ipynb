# %% [markdown]
# # Loan predictions
#
# ## Problem Statement
#
# We want to automate the loan eligibility process based on customer details that are provided as online application forms are being filled. You can find the dataset [here](https://drive.google.com/file/d/1h_jl9xqqqHflI5PsuiQd_soNYxzFfjKw/view?usp=sharing). These details concern the customer's Gender, Marital Status, Education, Number of Dependents, Income, Loan Amount, Credit History and other things as well.
#
# |Variable| Description|
# |: ------------- |:-------------|
# |Loan_ID| Unique Loan ID|
# |Gender| Male/ Female|
# |Married| Applicant married (Y/N)|
# |Dependents| Number of dependents|
# |Education| Applicant Education (Graduate/ Under Graduate)|
# |Self_Employed| Self employed (Y/N)|
# |ApplicantIncome| Applicant income|
# |CoapplicantIncome| Coapplicant income|
# |LoanAmount| Loan amount in thousands|
# |Loan_Amount_Term| Term of loan in months|
# |Credit_History| credit history meets guidelines|
# |Property_Area| Urban/ Semi Urban/ Rural|
# |Loan_Status| Loan approved (Y/N)
#
#
#
# ### Explore the problem in following stages:
#
# 1. Hypothesis Generation – understanding the problem better by brainstorming possible factors that can impact the outcome
# 2. Data Exploration – looking at categorical and continuous feature summaries and making inferences about the data.
# 3. Data Cleaning – imputing missing values in the data and checking for outliers
# 4. Feature Engineering – modifying existing variables and creating new ones for analysis
# 5. Model Building – making predictive models on the data

# %% [markdown]
# ## 1. Hypothesis Generation
#
# Generating a hypothesis is a major step in the process of analyzing data. This involves understanding the problem and formulating a meaningful hypothesis about what could potentially have a good impact on the outcome. This is done BEFORE looking at the data, and we end up creating a laundry list of the different analyses which we can potentially perform if data is available.
#
# #### Possible hypotheses
# Which applicants are more likely to get a loan
#
# 1. Applicants having a credit history
# 2. Applicants with higher applicant and co-applicant incomes
# 3. Applicants with higher education level
# 4. Properties in urban areas with high growth perspectives
#
# Do more brainstorming and create some hypotheses of your own. Remember that the data might not be sufficient to test all of these, but forming these enables a better understanding of the problem.

# %% [markdown]
# ## 2. Data Exploration
# Let's do some basic data exploration here and come up with some inferences about the data. Go ahead and try to figure out some irregularities and address them in the next section.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
df = pd.read_csv("data.csv") 
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# 2             1.0         Urban           Y
# 3             1.0         Urban           Y
# 4             1.0         Urban           Y

# %% [markdown]
# One of the key challenges in any data set are missing values. Lets start by checking which columns contain missing values.

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %% [markdown]
# Look at some basic statistics for numerical variables.

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# 1. How many applicants have a `Credit_History`? (`Credit_History` has value 1 for those who have a credit history and 0 otherwise)
# 2. Is the `ApplicantIncome` distribution in line with your expectation? Similarly, what about `CoapplicantIncome`?
# 3. Tip: Can you see a possible skewness in the data by comparing the mean to the median, i.e. the 50% figure of a feature.

# %% [markdown]
# Let's discuss nominal (categorical) variable. Look at the number of unique values in each of them.

# %%
df.select_dtypes('object').nunique()
# Out:
# Loan_ID          614
# Gender             2
# Married            2
# Dependents         4
# Education          2
# Self_Employed      2
# Property_Area      3
# Loan_Status        2
# dtype: int64

# %% [markdown]
# Explore further using the frequency of different categories in each nominal variable. Exclude the ID obvious reasons.

# %%
df_cat=df.select_dtypes('object').drop('Loan_ID',axis=1)

# %%
#Applicants having a credit history? yes
df.groupby('Credit_History').count()
# Out:
#                 Loan_ID  Gender  Married  Dependents  Education  \
# Credit_History
# 0.0                  89      86       89          84         89
# 1.0                 475     466      472         465        475
#
#                 Self_Employed  ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Credit_History
# 0.0                        88               89                 89          85
# 1.0                       450              475                475         458
#
#                 Loan_Amount_Term  Property_Area  Loan_Status
# Credit_History
# 0.0                           83             89           89
# 1.0                          467            475          475

# %%
# Applicants with higher applicant and co-applicant incomes
df.groupby('Credit_History')['Loan_Status'].count()
# Out:
# Credit_History
# 0.0     89
# 1.0    475
# Name: Loan_Status, dtype: int64

# %%
# Properties in urban areas with high growth perspectives
df.groupby('Property_Area')['Loan_Status'].count()
# Out:
# Property_Area
# Rural        179
# Semiurban    233
# Urban        202
# Name: Loan_Status, dtype: int64

# %%
df_cat.groupby('Gender')['Loan_Status'].count()
# Out:
# Gender
# Female    112
# Male      489
# Name: Loan_Status, dtype: int64

# %%
# Applicants with higher education level
df_cat.groupby('Education')['Loan_Status'].count()
# Out:
# Education
# Graduate        480
# Not Graduate    134
# Name: Loan_Status, dtype: int64

# %%
df_cat.groupby('Property_Area')['Loan_Status'].count()
# Out:
# Property_Area
# Rural        179
# Semiurban    233
# Urban        202
# Name: Loan_Status, dtype: int64

# %% [markdown]
# ### Distribution analysis
#
# Study distribution of various variables. Plot the histogram of ApplicantIncome, try different number of bins.

# %%
new=df[['ApplicantIncome','Loan_Status']]
sns.displot(df['ApplicantIncome'],bins=300,kde=True)
plt.xlim(0,20000)
plt.axvline(df['ApplicantIncome'].mean(),color='red',ls='--',label='mean')
plt.axvline(df['ApplicantIncome'].median(),color='blue',ls='--',label='median')
plt.legend()
plt.show()

# %% [markdown]
# Look at box plots to understand the distributions.

# %%
sns.boxplot(x=df['ApplicantIncome'],data=df)
# Out:
# <AxesSubplot:xlabel='ApplicantIncome'>

# %% [markdown]
# Look at the distribution of income segregated  by `Education`

# %%
df.columns
sns.histplot(x='ApplicantIncome',hue='Education',data=df)
plt.xlim(0,25000)
# Out:
# (0.0, 25000.0)

# %% [markdown]
# Look at the histogram and boxplot of LoanAmount

# %%
sns.histplot(x='LoanAmount',data=df,kde=True)
# Out:
# <AxesSubplot:xlabel='LoanAmount', ylabel='Count'>

# %%
sns.boxplot(x='LoanAmount',data=df)
# Out:
# <AxesSubplot:xlabel='LoanAmount'>

# %% [markdown]
# There might be some extreme values. Both `ApplicantIncome` and `LoanAmount` require some amount of data munging. `LoanAmount` has missing and well as extreme values values, while `ApplicantIncome` has a few extreme values, which demand deeper understanding.

# %% [markdown]
# ### Categorical variable analysis
#
# Try to understand categorical variables in more details using `pandas.DataFrame.pivot_table` and some visualizations.

# %%
df.columns
# Out:
# Index(['Loan_ID', 'Gender', 'Married', 'Dependents', 'Education',
#        'Self_Employed', 'ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Property_Area', 'Loan_Status'],
#       dtype='object')

# %%
sns.boxplot(x='Married',y='LoanAmount',hue='Gender',data=df)
# Out:
# <AxesSubplot:xlabel='Married', ylabel='LoanAmount'>

# %%
pd.DataFrame.pivot_table(df,values='LoanAmount',columns='Credit_History',index=['Gender','Married'],aggfunc=np.mean)
# Out:
# Credit_History         0.0         1.0
# Gender Married
# Female No       108.416667  114.745763
#        Yes      172.250000  156.434783
# Male   No       132.842105  131.880000
#        Yes      161.212766  151.950943

# %%
#Applicants having a credit history?

# %%
sns.pairplot(df,hue='Loan_Status')

# %% [markdown]
# ## 3. Data Cleaning
#
# This step typically involves imputing missing values and treating outliers.

# %% [markdown]
# ### Imputing Missing Values
#
# Missing values may not always be NaNs. For instance, the `Loan_Amount_Term` might be 0, which does not make sense.

# %% [markdown]
# Impute missing values for all columns. Use the values which you find most meaningful (mean, mode, median, zero.... maybe different mean values for different groups)

# %%
df.isnull().sum()
# Out:
# Loan_ID               0
# Gender               13
# Married               3
# Dependents           15
# Education             0
# Self_Employed        32
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount           22
# Loan_Amount_Term     14
# Credit_History       50
# Property_Area         0
# Loan_Status           0
# dtype: int64

# %%
df.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       614.000000         614.000000  592.000000         600.00000
# mean       5403.459283        1621.245798  146.412162         342.00000
# std        6109.041673        2926.248369   85.587325          65.12041
# min         150.000000           0.000000    9.000000          12.00000
# 25%        2877.500000           0.000000  100.000000         360.00000
# 50%        3812.500000        1188.500000  128.000000         360.00000
# 75%        5795.000000        2297.250000  168.000000         360.00000
# max       81000.000000       41667.000000  700.000000         480.00000
#
#        Credit_History
# count      564.000000
# mean         0.842199
# std          0.364878
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %%
df.drop('Loan_ID',axis=1,inplace=True)

# %%
df.Loan_Amount_Term.unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
df['Gender']=df['Gender'].fillna(lambda x: random.choice('Male','Female'))

# %%
df[['Self_Employed','Dependents']]=df[['Self_Employed','Dependents']].fillna(0)

# %%
df['Credit_History']=df['Credit_History'].fillna(1)

# %%
df.Loan_Amount_Term.unique()
# Out:
# array([360., 120., 240.,  nan, 180.,  60., 300., 480.,  36.,  84.,  12.])

# %%
df['Loan_Amount_Term']=df['Loan_Amount_Term'].fillna(360)

# %%
df['LoanAmount']=df['LoanAmount'].fillna(df['LoanAmount'].mean())

# %%
df.Married.unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
df['Married']=df['Married'].fillna('No')

# %%
df.isnull().sum()
# Out:
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# Loan_Status          0
# dtype: int64

# %%
df.Dependents=df.Dependents.astype('str')

# %%
df.Credit_History=df.Credit_History.astype('str')

# %% [markdown]
# ### Extreme values
# Try a log transformation to get rid of the extreme values in `LoanAmount`. Plot the histogram before and after the transformation

# %%
df['LoanAmount_log']=np.log(df['LoanAmount'])

# %%
sns.histplot(x='LoanAmount_log',hue='Loan_Status',data=df,kde=True)
# Out:
# <AxesSubplot:xlabel='LoanAmount_log', ylabel='Count'>

# %% [markdown]
# Combine both incomes as total income and take a log transformation of the same.

# %%
income = df['ApplicantIncome']+df['CoapplicantIncome']
df['logincome']=np.log10(income)

# %%
sns.histplot(x='logincome',hue='Loan_Status',data=df,kde=True)
# Out:
# <AxesSubplot:xlabel='logincome', ylabel='Count'>

# %% [markdown]
# ## 4. Building a Predictive Model

# %% [markdown]
# Try paramater grid search to improve the results

# %% [markdown]
# ## 5. Using Pipeline
# If you didn't use pipelines before, transform your data prep, feat. engineering and modeling steps into Pipeline. It will be helpful for deployment.
#
# The goal here is to create the pipeline that will take one row of our dataset and predict the probability of being granted a loan.
#
# `pipeline.predict(x)`

# %%
from sklearn.model_selection import train_test_split # For train/test splits
from sklearn.ensemble import RandomForestClassifier # The k-nearest neighbor classifier
from sklearn.feature_selection import SelectKBest # Feature selector
from sklearn.pipeline import Pipeline # For setting up pipeline
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import StandardScaler, LabelEncoder,OneHotEncoder
from sklearn.model_selection import GridSearchCV # For optimization

# %%
dff=pd.read_csv('data.csv')

# %%
dff.drop('Loan_ID',axis=1,inplace=True)

# %%
X=dff.drop('Loan_Status',axis=1)

# %%
y=dff['Loan_Status']

# %%
X.Credit_History=X.Credit_History.astype('str')

# %%
cat_feats=X.dtypes[X.dtypes == 'object'].index.tolist()
num_feats=X.dtypes[~X.dtypes.index.isin(cat_feats)].index.tolist()

# %%
cat_feats
# Out:
# ['Gender',
#  'Married',
#  'Dependents',
#  'Education',
#  'Self_Employed',
#  'Credit_History',
#  'Property_Area']

# %%
num_feats
# Out:
# ['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term']

# %%
le = LabelEncoder()
y = le.fit_transform(y)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,  
    y, 
    test_size=1/3,
    random_state=0)

# %%
from sklearn.preprocessing import FunctionTransformer
from sklearn.pipeline import Pipeline, FeatureUnion
from sklearn.impute import SimpleImputer

# Using own function in Pipeline
# def numFeat(data):
#     return data[num_feats]

# %%
def log_transform(x):
    return np.log(x+1)

# %%
# we will start two separate pipelines for each type of features
log_trans = FunctionTransformer(log_transform)

# %%
basemodel=RandomForestClassifier()

# %%
numeric_transform=Pipeline(steps=[
                            ('imputer',SimpleImputer(strategy='mean')),
                            ('numeric',log_trans),
                            ('scale',StandardScaler()),
])

# %%
cat_transform=Pipeline(steps=[('imputer',SimpleImputer(strategy='most_frequent')),
                        ('onehotencoded',OneHotEncoder(handle_unknown='ignore',sparse=False))    
])

# %%
preprocess=ColumnTransformer(transformers=[
    ('num',numeric_transform,num_feats),
    ('cat',cat_transform,cat_feats)  
])

# %%
pipeline=Pipeline(steps=[("preprocessor",preprocess),
                   ("clf",basemodel) #base_model=Ridge()
])

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(transformers=[('num',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer()),
#                                                                   ('numeric',
#                                                                    FunctionTransformer(func=<function log_transform at 0x7fd3c0956d30>)),
#                                                                   ('scale',
#                                                                    StandardScaler())]),
#                                                   ['ApplicantIncome',
#                                                    'CoapplicantIncome',
#                                                    'LoanAmount',
#                                                    'Loan_Amount_Term']),
#                                                  ('cat',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('onehotencoded',
#                                                                    OneHotEncoder(handle_unknown='ignore',
#                                                                                  sparse=False))]),
#                                                   ['Gender', 'Married',
#                                                    'Dependents', 'Education',
#                                                    'Self_Employed',
#                                                    'Credit_History',
#                                                    'Property_Area'])])),
#                 ('clf', RandomForestClassifier())])

# %%
from sklearn.metrics import accuracy_score

# %%
y_pred = pipeline.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)
acc
# Out:
# 0.8

# %%
from sklearn.svm import SVC
from sklearn.linear_model import LogisticRegression
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
param_grid = {'clf': [SVC(), RandomForestClassifier(),
                        XGBClassifier(),
                        KNeighborsClassifier()]}

# %%
grid=GridSearchCV(pipeline,param_grid=param_grid,cv=5)

# %%
grid.fit(X_train,y_train)
# Out:
# /Users/oliviahan/opt/anaconda3/envs/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/oliviahan/opt/anaconda3/envs/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [18:45:58] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1645117948562/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:45:58] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1645117948562/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/oliviahan/opt/anaconda3/envs/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/oliviahan/opt/anaconda3/envs/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [18:45:58] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1645117948562/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [18:45:58] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1645117948562/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# /Users/oliviahan/opt/anaconda3/envs/venv/lib/python3.9/site-packages/xgboost/sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [18:45:59] WARNING: /Users/runner/miniforge3/conda-bld/xgboost-split_1645117948562/work/src/learner.cc:1115: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('numeric',
#                                                                                           FunctionTransformer(func=<function log_transform at 0x7fd3c0956d30>)),
#                                                                                          ('scale',
#                                                                                           StandardScaler())]),
#                                                                          ['ApplicantIncome',
#                                                                           'CoapplicantIncome',
#                                                                           'LoanAmount',
#                                                                           'Loan_Amount_Term']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('im...
#                                                learning_rate=None,
#                                                max_delta_step=None,
#                                                max_depth=None,
#                                                min_child_weight=None,
#                                                missing=nan,
#                                                monotone_constraints=None,
#                                                n_estimators=100, n_jobs=None,
#                                                num_parallel_tree=None,
#                                                predictor=None,
#                                                random_state=None,
#                                                reg_alpha=None, reg_lambda=None,
#                                                scale_pos_weight=None,
#                                                subsample=None, tree_method=None,
#                                                validate_parameters=None,
#                                                verbosity=None),
#                                  KNeighborsClassifier()]})

# %%
grid.best_params_
# Out:
# {'clf': SVC()}

# %%
grid.score(X_test,y_test)
# Out:
# 0.8146341463414634

# %%
parms={'clf':[SVC(probability=True)],
       'clf__gamma':['scale','auto'],
       'clf__degree':[3,6,9],
       'clf__C':[1,10,100],
       'clf__kernel':['linear','rbf']   
}

# %%
grid=GridSearchCV(pipeline,param_grid=parms,cv=5,verbose=2)

# %%
grid.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 36 candidates, totalling 180 fits
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=scale, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=scale, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=scale, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=scale, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=3, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=scale, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=scale, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=scale, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=scale, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=scale, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=scale, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=scale, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=auto, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=6, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=scale, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=scale, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=scale, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=scale, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=1, clf__degree=9, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=scale, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=scale, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=auto, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=auto, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=3, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=scale, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=scale, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=auto, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=6, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=scale, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=scale, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=scale, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=scale, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=scale, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=scale, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=auto, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=auto, clf__kernel=linear; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=auto, clf__kernel=linear; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=auto, clf__kernel=rbf; total time=   0.0s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=10, clf__degree=9, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=scale, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=scale, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=scale, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=scale, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=scale, clf__kernel=linear; total time=   0.5s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=auto, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=auto, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=auto, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=auto, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=auto, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=3, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=scale, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=scale, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=scale, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=scale, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=scale, clf__kernel=linear; total time=   0.3s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=auto, clf__kernel=linear; total time=   0.3s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=auto, clf__kernel=linear; total time=   0.3s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=auto, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=auto, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=auto, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=6, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=scale, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=scale, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=scale, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=scale, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=scale, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=scale, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=auto, clf__kernel=linear; total time=   0.3s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=auto, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=auto, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=auto, clf__kernel=linear; total time=   0.3s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=auto, clf__kernel=linear; total time=   0.2s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# [CV] END clf=SVC(probability=True), clf__C=100, clf__degree=9, clf__gamma=auto, clf__kernel=rbf; total time=   0.1s
# GridSearchCV(cv=5,
#              estimator=Pipeline(steps=[('preprocessor',
#                                         ColumnTransformer(transformers=[('num',
#                                                                          Pipeline(steps=[('imputer',
#                                                                                           SimpleImputer()),
#                                                                                          ('numeric',
#                                                                                           FunctionTransformer(func=<function log_transform at 0x7fd3c0956d30>)),
#                                                                                          ('scale',
#                                                                                           StandardScaler())]),
#                                                                          ['ApplicantIncome',
#                                                                           'CoapplicantIncome',
#                                                                           'LoanAmount',
#                                                                           'Loan_Amount_Term']),
#                                                                         ('cat',
#                                                                          Pipeline(steps=[('im...
#                                                                                           OneHotEncoder(handle_unknown='ignore',
#                                                                                                         sparse=False))]),
#                                                                          ['Gender',
#                                                                           'Married',
#                                                                           'Dependents',
#                                                                           'Education',
#                                                                           'Self_Employed',
#                                                                           'Credit_History',
#                                                                           'Property_Area'])])),
#                                        ('clf', RandomForestClassifier())]),
#              param_grid={'clf': [SVC(C=1, kernel='linear', probability=True)],
#                          'clf__C': [1, 10, 100], 'clf__degree': [3, 6, 9],
#                          'clf__gamma': ['scale', 'auto'],
#                          'clf__kernel': ['linear', 'rbf']},
#              verbose=2)

# %%
grid.best_params_
# Out:
# {'clf': SVC(C=1, kernel='linear', probability=True),
#  'clf__C': 1,
#  'clf__degree': 3,
#  'clf__gamma': 'scale',
#  'clf__kernel': 'linear'}

# %%
y_pred=grid.predict(X_test)

# %%
grid.score(X_test,y_test)
# Out:
# 0.8195121951219512

# %%
from sklearn import metrics

# %%
metrics.confusion_matrix(y_test,y_pred)
# Out:
# array([[ 25,  35],
#        [  2, 143]])

# %%
print(metrics.classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      0.42      0.57        60
#            1       0.80      0.99      0.89       145
#
#     accuracy                           0.82       205
#    macro avg       0.86      0.70      0.73       205
# weighted avg       0.84      0.82      0.79       205

# %%
print(metrics.roc_auc_score(y_test, y_pred))
# Out:
# 0.7014367816091953

# %%
y_prob=grid.predict_proba(X_test)

# %%
metrics.plot_roc_curve(grid,X_test,y_test)
# Out:
# /Users/oliviahan/opt/anaconda3/envs/venv/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function plot_roc_curve is deprecated; Function :func:`plot_roc_curve` is deprecated in 1.0 and will be removed in 1.2. Use one of the class methods: :meth:`sklearn.metric.RocCurveDisplay.from_predictions` or :meth:`sklearn.metric.RocCurveDisplay.from_estimator`.
#   warnings.warn(msg, category=FutureWarning)

# %%
fpr, tpr, threshold = metrics.roc_curve(y_test, y_pred)
roc_auc = metrics.auc(fpr, tpr)

# %%
plt.title('ROC curve')
plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.show()

# %% [markdown]
# ## 6. Deploy your model to cloud and test it with PostMan, BASH or Python

# %%
import pickle

# %%
pickle.dump(grid,open("model.p","wb"))

# %%
# http://10.0.0.148:5000/

# %%
X_train.dtypes
# Out:
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History        object
# Property_Area         object
# dtype: object

# %%
json_data = {
    "Gender": "Female",
    "Married": "No",
    "Dependents": "0",
    "Education": "Graduate",
    "Self_Employed": "No",
    "ApplicantIncome": 6000,
    "CoapplicantIncome": 0.0,
    "LoanAmount": 300.0,
    "Loan_Amount_Term": 360.0,
    "Credit_History": "1.0",
    "Property_Area": "Semiurban"
}

# %%
import requests
URL = 'http://10.0.0.148:5000/scoring'
# sending get request and saving the response as response object 
r = requests.post(url = URL, json = json_data) 
r.status_code
# Out:
# 200

# %%
print(r.json())
# Out:
# [1]

# %%
X_train.iloc[1]
# Out:
# Gender                    NaN
# Married                   Yes
# Dependents                  0
# Education            Graduate
# Self_Employed             Yes
# ApplicantIncome           674
# CoapplicantIncome      5296.0
# LoanAmount              168.0
# Loan_Amount_Term        360.0
# Credit_History            1.0
# Property_Area           Rural
# Name: 188, dtype: object

# %%
X_train.dtypes
# Out:
# Gender                object
# Married               object
# Dependents            object
# Education             object
# Self_Employed         object
# ApplicantIncome        int64
# CoapplicantIncome    float64
# LoanAmount           float64
# Loan_Amount_Term     float64
# Credit_History        object
# Property_Area         object
# dtype: object
